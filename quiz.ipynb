# %%
fruit = {}
def addone(index):
    if index in fruit:
        fruit[index] += 1
    else:
        fruit[index] = 1

addone("Apple")
addone("banana")
addone("apple")
print(fruit)
print(len(fruit))
# Out:
# {'Apple': 1, 'banana': 1, 'apple': 1}
# 3

# %%
arr = {}
arr[1] = 1
arr['1']= 2
arr[1] += 1

print(arr)

sum = 0
for k in arr:
    sum += arr[k]
print(sum)
# Out:
# {1: 2, '1': 2}
# 4
